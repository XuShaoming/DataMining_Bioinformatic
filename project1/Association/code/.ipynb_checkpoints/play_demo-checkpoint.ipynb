# %%
import numpy as np
from io import StringIO

# %%
def get_data(filename):
    with open('../data/associationruletestdata.txt') as f:
        raw_data = np.genfromtxt(StringIO(f.read()), delimiter="\t",dtype='str')
        data = raw_data[:,:-1]
        label = raw_data[:,-1]
    return data, label

# %%
def pre_process(data):
    for i in range(len(data)):
        for j in range(len(data[i])):
            data[i,j] = 'G' + str(j) + '_' + data[i,j]

# %%
def createC1(data):
    C1 = []
    for row in data:
        for item in row:
            if [item] not in C1:
                C1.append([item])  
    return list(map(frozenset, C1))

# %%
def scanD(D, Ck, minSupport):
    ssCnt = {}
    for tid in D:
        for can in Ck:
            if can.issubset(tid):
                if not can in ssCnt:
                    ssCnt[can]=1
                else: 
                    ssCnt[can] += 1
    numItems = float(len(D))
    retList = []
    supportData = {}
    for key in ssCnt:
        support = ssCnt[key]/numItems
        if support >= minSupport:
            retList.append(key)
        supportData[key] = support
    return retList, supportData

# %%
def aprioriGen(Lk, k): #creates Ck
    retList = []
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i+1, lenLk): 
            L1 = list(Lk[i])[:k-2]
            L2 = list(Lk[j])[:k-2]
            L1.sort()
            L2.sort()
            if L1==L2: #if first k-2 elements are equal
                retList.append(Lk[i] | Lk[j]) #set union
    return retList

# %%
def apriori(dataSet, minSupport = 0.5):
    C1 = createC1(dataSet)
    D = list(map(set, dataSet))
    L1, supportData = scanD(D, C1, minSupport)
    L = [L1]
    k = 2
    while (len(L[k-2]) > 0):
        Ck = aprioriGen(L[k-2], k)
        Lk, supK = scanD(D, Ck, minSupport)#scan DB to get Lk
        supportData.update(supK)
        L.append(Lk)
        k += 1
    return L, supportData

# %%
def generateRules(L, supportData, minConf=0.7):  #supportData is a dict coming from scanD
    bigRuleList = []
    for i in range(1, len(L)):#only get the sets with two or more items
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]
            if (i > 1):
                rulesFromConseq(freqSet, H1, supportData, bigRuleList, minConf)
            else:
                calcConf(freqSet, H1, supportData, bigRuleList, minConf)
    return bigRuleList

# %%
def calcConf(freqSet, H, supportData, brl, minConf=0.7):
    prunedH = [] #create new list to return
    for conseq in H:
        conf = supportData[freqSet]/supportData[freqSet-conseq] #calc confidence
        if conf >= minConf: 
            print (freqSet-conseq,'-->',conseq,'conf:',conf)
            brl.append((freqSet-conseq, conseq, conf))
            prunedH.append(conseq)
    return prunedH

# %%
def rulesFromConseq(freqSet, H, supportData, brl, minConf=0.7):
    m = len(H[0])
    if (len(freqSet) > (m + 1)): #try further merging
        Hmp1 = aprioriGen(H, m+1)#create Hm+1 new candidates
        Hmp1 = calcConf(freqSet, Hmp1, supportData, brl, minConf)
        if (len(Hmp1) > 1):    #need at least two sets to merge
            rulesFromConseq(freqSet, Hmp1, supportData, brl, minConf)

# %%
data, label = get_data('../data/associationruletestdata.txt')
pre_process(data)
#C1 = createC1(data)
#L1, SupportDat0 = scanD(data, C1, 0.5)
L, supportData = apriori(data, 0.5)

# %%
size = 0
for row in L:
    size += len(row)
size
# Out:
# 174

# %%
generateRules(L, supportData, 0.7)
# Out:
# frozenset({'G0_Up'}) --> frozenset({'G58_Up'}) conf: 0.7681159420289856
# frozenset({'G0_Up'}) --> frozenset({'G71_Up'}) conf: 0.7536231884057972
# frozenset({'G71_Up'}) --> frozenset({'G0_Up'}) conf: 0.7027027027027027
# frozenset({'G12_Down'}) --> frozenset({'G5_Up'}) conf: 0.7352941176470588
# frozenset({'G5_Up'}) --> frozenset({'G12_Down'}) conf: 0.7575757575757576
# frozenset({'G27_Down'}) --> frozenset({'G5_Up'}) conf: 0.7042253521126761
# frozenset({'G5_Up'}) --> frozenset({'G27_Down'}) conf: 0.7575757575757576
# frozenset({'G5_Up'}) --> frozenset({'G58_Up'}) conf: 0.7727272727272727
# frozenset({'G27_Down'}) --> frozenset({'G12_Down'}) conf: 0.7042253521126761
# frozenset({'G12_Down'}) --> frozenset({'G27_Down'}) conf: 0.7352941176470588
# frozenset({'G12_Down'}) --> frozenset({'G58_Up'}) conf: 0.7941176470588235
# frozenset({'G58_Up'}) --> frozenset({'G12_Down'}) conf: 0.7105263157894737
# frozenset({'G12_Down'}) --> frozenset({'G71_Up'}) conf: 0.7794117647058824
# frozenset({'G71_Up'}) --> frozenset({'G12_Down'}) conf: 0.7162162162162162
# frozenset({'G12_Down'}) --> frozenset({'G81_Down'}) conf: 0.75
# frozenset({'G81_Down'}) --> frozenset({'G12_Down'}) conf: 0.75
# frozenset({'G27_Down'}) --> frozenset({'G51_Down'}) conf: 0.7323943661971831
# frozenset({'G51_Down'}) --> frozenset({'G27_Down'}) conf: 0.8
# frozenset({'G27_Down'}) --> frozenset({'G58_Up'}) conf: 0.7183098591549296
# frozenset({'G58_Up'}) --> frozenset({'G71_Up'}) conf: 0.8157894736842105
# frozenset({'G71_Up'}) --> frozenset({'G58_Up'}) conf: 0.8378378378378378
# frozenset({'G81_Down'}) --> frozenset({'G58_Up'}) conf: 0.838235294117647
# frozenset({'G58_Up'}) --> frozenset({'G81_Down'}) conf: 0.7499999999999999
# frozenset({'G95_Down'}) --> frozenset({'G58_Up'}) conf: 0.8591549295774649
# frozenset({'G58_Up'}) --> frozenset({'G95_Down'}) conf: 0.8026315789473684
# frozenset({'G81_Down'}) --> frozenset({'G71_Up'}) conf: 0.8529411764705881
# frozenset({'G71_Up'}) --> frozenset({'G81_Down'}) conf: 0.7837837837837838
# frozenset({'G95_Down'}) --> frozenset({'G71_Up'}) conf: 0.8309859154929577
# frozenset({'G71_Up'}) --> frozenset({'G95_Down'}) conf: 0.7972972972972973
# frozenset({'G96_Down'}) --> frozenset({'G71_Up'}) conf: 0.8360655737704918
# frozenset({'G95_Down'}) --> frozenset({'G81_Down'}) conf: 0.7323943661971831
# frozenset({'G81_Down'}) --> frozenset({'G95_Down'}) conf: 0.7647058823529411
# frozenset({'G81_Down'}) --> frozenset({'G96_Down'}) conf: 0.75
# frozenset({'G96_Down'}) --> frozenset({'G81_Down'}) conf: 0.8360655737704918
# frozenset({'G0_Up'}) --> frozenset({'G37_Down'}) conf: 0.7826086956521741
# frozenset({'G37_Down'}) --> frozenset({'G0_Up'}) conf: 0.7397260273972603
# frozenset({'G0_Up'}) --> frozenset({'G53_Up'}) conf: 0.7246376811594204
# frozenset({'G53_Up'}) --> frozenset({'G0_Up'}) conf: 0.7462686567164178
# frozenset({'G51_Down'}) --> frozenset({'G37_Down'}) conf: 0.8461538461538461
# frozenset({'G37_Down'}) --> frozenset({'G51_Down'}) conf: 0.7534246575342467
# frozenset({'G37_Down'}) --> frozenset({'G58_Up'}) conf: 0.726027397260274
# frozenset({'G86_Up'}) --> frozenset({'G58_Up'}) conf: 0.7611940298507462
# frozenset({'G87_Down'}) --> frozenset({'G58_Up'}) conf: 0.7746478873239437
# frozenset({'G58_Up'}) --> frozenset({'G87_Down'}) conf: 0.7236842105263158
# frozenset({'G1_Down'}) --> frozenset({'G37_Down'}) conf: 0.7575757575757576
# frozenset({'G37_Down'}) --> frozenset({'G46_Up'}) conf: 0.7397260273972603
# frozenset({'G46_Up'}) --> frozenset({'G37_Down'}) conf: 0.8181818181818182
# frozenset({'G64_Down'}) --> frozenset({'G37_Down'}) conf: 0.819672131147541
# frozenset({'G87_Down'}) --> frozenset({'G37_Down'}) conf: 0.7042253521126761
# frozenset({'G87_Down'}) --> frozenset({'G53_Up'}) conf: 0.7323943661971831
# frozenset({'G53_Up'}) --> frozenset({'G87_Down'}) conf: 0.7761194029850746
# frozenset({'G86_Up'}) --> frozenset({'G87_Down'}) conf: 0.8059701492537313
# frozenset({'G87_Down'}) --> frozenset({'G86_Up'}) conf: 0.7605633802816902
# frozenset({'G5_Up'}) --> frozenset({'G31_Down'}) conf: 0.7575757575757576
# frozenset({'G31_Down'}) --> frozenset({'G5_Up'}) conf: 0.7352941176470588
# frozenset({'G23_Down'}) --> frozenset({'G53_Up'}) conf: 0.7936507936507936
# frozenset({'G53_Up'}) --> frozenset({'G23_Down'}) conf: 0.7462686567164178
# frozenset({'G27_Down'}) --> frozenset({'G1_Down'}) conf: 0.7042253521126761
# frozenset({'G1_Down'}) --> frozenset({'G27_Down'}) conf: 0.7575757575757576
# frozenset({'G27_Down'}) --> frozenset({'G86_Up'}) conf: 0.7323943661971831
# frozenset({'G86_Up'}) --> frozenset({'G27_Down'}) conf: 0.7761194029850746
# frozenset({'G27_Down'}) --> frozenset({'G31_Down'}) conf: 0.7042253521126761
# frozenset({'G31_Down'}) --> frozenset({'G27_Down'}) conf: 0.7352941176470588
# frozenset({'G31_Down'}) --> frozenset({'G58_Up'}) conf: 0.7647058823529411
# frozenset({'G31_Down'}) --> frozenset({'G71_Up'}) conf: 0.7352941176470588
# frozenset({'G27_Down'}) --> frozenset({'G37_Down'}) conf: 0.7746478873239437
# frozenset({'G37_Down'}) --> frozenset({'G27_Down'}) conf: 0.7534246575342467
# frozenset({'G27_Down'}) --> frozenset({'G46_Up'}) conf: 0.7183098591549296
# frozenset({'G46_Up'}) --> frozenset({'G27_Down'}) conf: 0.7727272727272727
# frozenset({'G31_Down'}) --> frozenset({'G37_Down'}) conf: 0.7794117647058824
# frozenset({'G37_Down'}) --> frozenset({'G31_Down'}) conf: 0.726027397260274
# frozenset({'G90_Up'}) --> frozenset({'G37_Down'}) conf: 0.8153846153846154
# frozenset({'G37_Down'}) --> frozenset({'G90_Up'}) conf: 0.726027397260274
# frozenset({'G93_Up'}) --> frozenset({'G37_Down'}) conf: 0.8225806451612904
# frozenset({'G69_Down'}) --> frozenset({'G0_Up'}) conf: 0.7575757575757576
# frozenset({'G0_Up'}) --> frozenset({'G69_Down'}) conf: 0.7246376811594204
# frozenset({'G0_Up'}) --> frozenset({'G9_Down'}) conf: 0.7246376811594204
# frozenset({'G9_Down'}) --> frozenset({'G0_Up'}) conf: 0.7142857142857143
# frozenset({'G23_Down'}) --> frozenset({'G87_Down'}) conf: 0.7936507936507936
# frozenset({'G87_Down'}) --> frozenset({'G23_Down'}) conf: 0.7042253521126761
# frozenset({'G27_Down'}) --> frozenset({'G87_Down'}) conf: 0.7323943661971831
# frozenset({'G87_Down'}) --> frozenset({'G27_Down'}) conf: 0.7323943661971831
# frozenset({'G27_Down'}) --> frozenset({'G9_Down'}) conf: 0.7183098591549296
# frozenset({'G9_Down'}) --> frozenset({'G27_Down'}) conf: 0.7285714285714286
# frozenset({'G27_Down'}) --> frozenset({'G40_Down'}) conf: 0.7183098591549296
# frozenset({'G40_Down'}) --> frozenset({'G27_Down'}) conf: 0.796875
# frozenset({'G9_Down'}) --> frozenset({'G58_Up'}) conf: 0.7142857142857143
# frozenset({'G9_Down'}) --> frozenset({'G46_Up'}) conf: 0.7285714285714286
# frozenset({'G46_Up'}) --> frozenset({'G9_Down'}) conf: 0.7727272727272727
# frozenset({'G87_Down'}) --> frozenset({'G7_Up'}) conf: 0.7183098591549296
# frozenset({'G7_Up'}) --> frozenset({'G87_Down'}) conf: 0.7727272727272727
# frozenset({'G9_Down'}) --> frozenset({'G87_Down'}) conf: 0.7428571428571429
# frozenset({'G87_Down'}) --> frozenset({'G9_Down'}) conf: 0.7323943661971831
# frozenset({'G87_Down'}) --> frozenset({'G40_Down'}) conf: 0.7323943661971831
# frozenset({'G40_Down'}) --> frozenset({'G87_Down'}) conf: 0.8125
# frozenset({'G69_Down'}) --> frozenset({'G9_Down'}) conf: 0.7575757575757576
# frozenset({'G9_Down'}) --> frozenset({'G69_Down'}) conf: 0.7142857142857143
# frozenset({'G66_Up'}) --> frozenset({'G0_Up'}) conf: 0.8064516129032259
# frozenset({'G0_Up'}) --> frozenset({'G66_Up'}) conf: 0.7246376811594204
# frozenset({'G5_Up'}) --> frozenset({'G37_Down'}) conf: 0.7575757575757576
# frozenset({'G69_Down'}) --> frozenset({'G37_Down'}) conf: 0.8181818181818182
# frozenset({'G37_Down'}) --> frozenset({'G69_Down'}) conf: 0.7397260273972603
# frozenset({'G9_Down'}) --> frozenset({'G37_Down'}) conf: 0.7571428571428572
# frozenset({'G37_Down'}) --> frozenset({'G9_Down'}) conf: 0.726027397260274
# frozenset({'G40_Down'}) --> frozenset({'G37_Down'}) conf: 0.78125
# frozenset({'G66_Up'}) --> frozenset({'G37_Down'}) conf: 0.8225806451612904
# frozenset({'G93_Up'}) --> frozenset({'G9_Down'}) conf: 0.8064516129032259
# frozenset({'G9_Down'}) --> frozenset({'G93_Up'}) conf: 0.7142857142857143
# frozenset({'G81_Down'}) --> frozenset({'G71_Up', 'G58_Up'}) conf: 0.7647058823529411
# frozenset({'G71_Up'}) --> frozenset({'G58_Up', 'G81_Down'}) conf: 0.7027027027027027
# frozenset({'G95_Down'}) --> frozenset({'G71_Up', 'G58_Up'}) conf: 0.7183098591549296
# [(frozenset({'G0_Up'}), frozenset({'G58_Up'}), 0.7681159420289856),
#  (frozenset({'G0_Up'}), frozenset({'G71_Up'}), 0.7536231884057972),
#  (frozenset({'G71_Up'}), frozenset({'G0_Up'}), 0.7027027027027027),
#  (frozenset({'G12_Down'}), frozenset({'G5_Up'}), 0.7352941176470588),
#  (frozenset({'G5_Up'}), frozenset({'G12_Down'}), 0.7575757575757576),
#  (frozenset({'G27_Down'}), frozenset({'G5_Up'}), 0.7042253521126761),
#  (frozenset({'G5_Up'}), frozenset({'G27_Down'}), 0.7575757575757576),
#  (frozenset({'G5_Up'}), frozenset({'G58_Up'}), 0.7727272727272727),
#  (frozenset({'G27_Down'}), frozenset({'G12_Down'}), 0.7042253521126761),
#  (frozenset({'G12_Down'}), frozenset({'G27_Down'}), 0.7352941176470588),
#  (frozenset({'G12_Down'}), frozenset({'G58_Up'}), 0.7941176470588235),
#  (frozenset({'G58_Up'}), frozenset({'G12_Down'}), 0.7105263157894737),
#  (frozenset({'G12_Down'}), frozenset({'G71_Up'}), 0.7794117647058824),
#  (frozenset({'G71_Up'}), frozenset({'G12_Down'}), 0.7162162162162162),
#  (frozenset({'G12_Down'}), frozenset({'G81_Down'}), 0.75),
#  (frozenset({'G81_Down'}), frozenset({'G12_Down'}), 0.75),
#  (frozenset({'G27_Down'}), frozenset({'G51_Down'}), 0.7323943661971831),
#  (frozenset({'G51_Down'}), frozenset({'G27_Down'}), 0.8),
#  (frozenset({'G27_Down'}), frozenset({'G58_Up'}), 0.7183098591549296),
#  (frozenset({'G58_Up'}), frozenset({'G71_Up'}), 0.8157894736842105),
#  (frozenset({'G71_Up'}), frozenset({'G58_Up'}), 0.8378378378378378),
#  (frozenset({'G81_Down'}), frozenset({'G58_Up'}), 0.838235294117647),
#  (frozenset({'G58_Up'}), frozenset({'G81_Down'}), 0.7499999999999999),
#  (frozenset({'G95_Down'}), frozenset({'G58_Up'}), 0.8591549295774649),
#  (frozenset({'G58_Up'}), frozenset({'G95_Down'}), 0.8026315789473684),
#  (frozenset({'G81_Down'}), frozenset({'G71_Up'}), 0.8529411764705881),
#  (frozenset({'G71_Up'}), frozenset({'G81_Down'}), 0.7837837837837838),
#  (frozenset({'G95_Down'}), frozenset({'G71_Up'}), 0.8309859154929577),
#  (frozenset({'G71_Up'}), frozenset({'G95_Down'}), 0.7972972972972973),
#  (frozenset({'G96_Down'}), frozenset({'G71_Up'}), 0.8360655737704918),
#  (frozenset({'G95_Down'}), frozenset({'G81_Down'}), 0.7323943661971831),
#  (frozenset({'G81_Down'}), frozenset({'G95_Down'}), 0.7647058823529411),
#  (frozenset({'G81_Down'}), frozenset({'G96_Down'}), 0.75),
#  (frozenset({'G96_Down'}), frozenset({'G81_Down'}), 0.8360655737704918),
#  (frozenset({'G0_Up'}), frozenset({'G37_Down'}), 0.7826086956521741),
#  (frozenset({'G37_Down'}), frozenset({'G0_Up'}), 0.7397260273972603),
#  (frozenset({'G0_Up'}), frozenset({'G53_Up'}), 0.7246376811594204),
#  (frozenset({'G53_Up'}), frozenset({'G0_Up'}), 0.7462686567164178),
#  (frozenset({'G51_Down'}), frozenset({'G37_Down'}), 0.8461538461538461),
#  (frozenset({'G37_Down'}), frozenset({'G51_Down'}), 0.7534246575342467),
#  (frozenset({'G37_Down'}), frozenset({'G58_Up'}), 0.726027397260274),
#  (frozenset({'G86_Up'}), frozenset({'G58_Up'}), 0.7611940298507462),
#  (frozenset({'G87_Down'}), frozenset({'G58_Up'}), 0.7746478873239437),
#  (frozenset({'G58_Up'}), frozenset({'G87_Down'}), 0.7236842105263158),
#  (frozenset({'G1_Down'}), frozenset({'G37_Down'}), 0.7575757575757576),
#  (frozenset({'G37_Down'}), frozenset({'G46_Up'}), 0.7397260273972603),
#  (frozenset({'G46_Up'}), frozenset({'G37_Down'}), 0.8181818181818182),
#  (frozenset({'G64_Down'}), frozenset({'G37_Down'}), 0.819672131147541),
#  (frozenset({'G87_Down'}), frozenset({'G37_Down'}), 0.7042253521126761),
#  (frozenset({'G87_Down'}), frozenset({'G53_Up'}), 0.7323943661971831),
#  (frozenset({'G53_Up'}), frozenset({'G87_Down'}), 0.7761194029850746),
#  (frozenset({'G86_Up'}), frozenset({'G87_Down'}), 0.8059701492537313),
#  (frozenset({'G87_Down'}), frozenset({'G86_Up'}), 0.7605633802816902),
#  (frozenset({'G5_Up'}), frozenset({'G31_Down'}), 0.7575757575757576),
#  (frozenset({'G31_Down'}), frozenset({'G5_Up'}), 0.7352941176470588),
#  (frozenset({'G23_Down'}), frozenset({'G53_Up'}), 0.7936507936507936),
#  (frozenset({'G53_Up'}), frozenset({'G23_Down'}), 0.7462686567164178),
#  (frozenset({'G27_Down'}), frozenset({'G1_Down'}), 0.7042253521126761),
#  (frozenset({'G1_Down'}), frozenset({'G27_Down'}), 0.7575757575757576),
#  (frozenset({'G27_Down'}), frozenset({'G86_Up'}), 0.7323943661971831),
#  (frozenset({'G86_Up'}), frozenset({'G27_Down'}), 0.7761194029850746),
#  (frozenset({'G27_Down'}), frozenset({'G31_Down'}), 0.7042253521126761),
#  (frozenset({'G31_Down'}), frozenset({'G27_Down'}), 0.7352941176470588),
#  (frozenset({'G31_Down'}), frozenset({'G58_Up'}), 0.7647058823529411),
#  (frozenset({'G31_Down'}), frozenset({'G71_Up'}), 0.7352941176470588),
#  (frozenset({'G27_Down'}), frozenset({'G37_Down'}), 0.7746478873239437),
#  (frozenset({'G37_Down'}), frozenset({'G27_Down'}), 0.7534246575342467),
#  (frozenset({'G27_Down'}), frozenset({'G46_Up'}), 0.7183098591549296),
#  (frozenset({'G46_Up'}), frozenset({'G27_Down'}), 0.7727272727272727),
#  (frozenset({'G31_Down'}), frozenset({'G37_Down'}), 0.7794117647058824),
#  (frozenset({'G37_Down'}), frozenset({'G31_Down'}), 0.726027397260274),
#  (frozenset({'G90_Up'}), frozenset({'G37_Down'}), 0.8153846153846154),
#  (frozenset({'G37_Down'}), frozenset({'G90_Up'}), 0.726027397260274),
#  (frozenset({'G93_Up'}), frozenset({'G37_Down'}), 0.8225806451612904),
#  (frozenset({'G69_Down'}), frozenset({'G0_Up'}), 0.7575757575757576),
#  (frozenset({'G0_Up'}), frozenset({'G69_Down'}), 0.7246376811594204),
#  (frozenset({'G0_Up'}), frozenset({'G9_Down'}), 0.7246376811594204),
#  (frozenset({'G9_Down'}), frozenset({'G0_Up'}), 0.7142857142857143),
#  (frozenset({'G23_Down'}), frozenset({'G87_Down'}), 0.7936507936507936),
#  (frozenset({'G87_Down'}), frozenset({'G23_Down'}), 0.7042253521126761),
#  (frozenset({'G27_Down'}), frozenset({'G87_Down'}), 0.7323943661971831),
#  (frozenset({'G87_Down'}), frozenset({'G27_Down'}), 0.7323943661971831),
#  (frozenset({'G27_Down'}), frozenset({'G9_Down'}), 0.7183098591549296),
#  (frozenset({'G9_Down'}), frozenset({'G27_Down'}), 0.7285714285714286),
#  (frozenset({'G27_Down'}), frozenset({'G40_Down'}), 0.7183098591549296),
#  (frozenset({'G40_Down'}), frozenset({'G27_Down'}), 0.796875),
#  (frozenset({'G9_Down'}), frozenset({'G58_Up'}), 0.7142857142857143),
#  (frozenset({'G9_Down'}), frozenset({'G46_Up'}), 0.7285714285714286),
#  (frozenset({'G46_Up'}), frozenset({'G9_Down'}), 0.7727272727272727),
#  (frozenset({'G87_Down'}), frozenset({'G7_Up'}), 0.7183098591549296),
#  (frozenset({'G7_Up'}), frozenset({'G87_Down'}), 0.7727272727272727),
#  (frozenset({'G9_Down'}), frozenset({'G87_Down'}), 0.7428571428571429),
#  (frozenset({'G87_Down'}), frozenset({'G9_Down'}), 0.7323943661971831),
#  (frozenset({'G87_Down'}), frozenset({'G40_Down'}), 0.7323943661971831),
#  (frozenset({'G40_Down'}), frozenset({'G87_Down'}), 0.8125),
#  (frozenset({'G69_Down'}), frozenset({'G9_Down'}), 0.7575757575757576),
#  (frozenset({'G9_Down'}), frozenset({'G69_Down'}), 0.7142857142857143),
#  (frozenset({'G66_Up'}), frozenset({'G0_Up'}), 0.8064516129032259),
#  (frozenset({'G0_Up'}), frozenset({'G66_Up'}), 0.7246376811594204),
#  (frozenset({'G5_Up'}), frozenset({'G37_Down'}), 0.7575757575757576),
#  (frozenset({'G69_Down'}), frozenset({'G37_Down'}), 0.8181818181818182),
#  (frozenset({'G37_Down'}), frozenset({'G69_Down'}), 0.7397260273972603),
#  (frozenset({'G9_Down'}), frozenset({'G37_Down'}), 0.7571428571428572),
#  (frozenset({'G37_Down'}), frozenset({'G9_Down'}), 0.726027397260274),
#  (frozenset({'G40_Down'}), frozenset({'G37_Down'}), 0.78125),
#  (frozenset({'G66_Up'}), frozenset({'G37_Down'}), 0.8225806451612904),
#  (frozenset({'G93_Up'}), frozenset({'G9_Down'}), 0.8064516129032259),
#  (frozenset({'G9_Down'}), frozenset({'G93_Up'}), 0.7142857142857143),
#  (frozenset({'G81_Down'}),
#   frozenset({'G58_Up', 'G71_Up'}),
#   0.7647058823529411),
#  (frozenset({'G71_Up'}),
#   frozenset({'G58_Up', 'G81_Down'}),
#   0.7027027027027027),
#  (frozenset({'G95_Down'}),
#   frozenset({'G58_Up', 'G71_Up'}),
#   0.7183098591549296)]
